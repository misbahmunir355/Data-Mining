# %%
#Time in terms of AM or PM.  (Discrete, qualitative, Nominal)
#Brightness as measured by a light meter.  (Continuous, quantitative, ratio)
#Brightness as measured by people’s judgments.  (Continuous, qualititative, ordinal)
#Angles as measured in degrees between 00 and 3600   (Continuous, quantitative, ratio)
#Bronze, Silver, and Gold medals as awarded at the Olympics.  (Discrete, qualititative, ordinal)
#Height above sea level.  (Continuous, quantitative, ratio)
#Number of patients in a hospital.  (Discrete, quantitative, ratio)
#ISBN numbers for books. (Look up the format on the Web.)  (Discrete, qualitative, Nominal)
#Ability to pass light in terms of the following values: opaque, translucent, transparent.  (Discrete, qualitative, ordinal)
#Military rank.  (Discrete, qualitative, ordinal)
#Distance from the center of campus.  (Continuous, quantitative, ratio)
#Density of a substance in grams per cubic centimeter.  (Continuous, quantitative, ratio)
#Coat check number. (When you attend an event, you can often give your coat to someone who,
#in turn, gives you a number that you can use to claim your coat when you leave.)   (Discrete, qualitative, Nominal)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/Iris - Iris.csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dependent_variable = 'Species'
independent_variables = data.columns[data.columns != dependent_variable]
print("Dependent Variable:", dependent_variable)
print("Independent Variables:", independent_variables)
# Out:
# Dependent Variable: Species
# Independent Variables: Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
print("Number of examples and features:")
print(data.shape)
# Out:
# Number of examples and features:
# (150, 6)

# %%
for column in data.columns:
    if data[column].dtype == 'object':
        print(f"\nValue counts for {column}:")
        print(data[column].value_counts())
# Out:
# Value counts for Species:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
print("\nCounts for each feature:")
print(data.dtypes.value_counts())
# Out:
# Counts for each feature:
# float64    4
# int64      1
# object     1
# dtype: int64

# %%
print("\nAttributes with missing values:")
print(data.isnull().sum())
# Out:
# Attributes with missing values:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
missing_values = data.isnull().sum()
if missing_values.any():
    print("Attributes with missing values:")
    print(missing_values)
else:
    print("No missing values in the dataset.")
# Out:
# No missing values in the dataset.

# %%
summary_stats = data.describe(include='all')

# %%
print("Mean for each attribute:")
print(summary_stats.loc['mean'])
# Out:
# Mean for each attribute:
# Id                   75.5
# SepalLengthCm    5.843333
# SepalWidthCm        3.054
# PetalLengthCm    3.758667
# PetalWidthCm     1.198667
# Species               NaN
# Name: mean, dtype: object

# %%
print("\nMedian for each attribute:")
print(data.median())
# Out:
# Median for each attribute:
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64
# <ipython-input-53-75c7b549a629>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.median())

# %%
print("\nMode for each attribute:")
print(data.mode().iloc[0]) # Mode may have multiple values, so selecting the first one
# Out:
# Mode for each attribute:
# Id                         1
# SepalLengthCm            5.0
# SepalWidthCm             3.0
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
print("\nRange for each attribute:")
print(summary_stats.loc['max'] - summary_stats.loc['min'])
# Out:
# Range for each attribute:
# Id               149.0
# SepalLengthCm      3.6
# SepalWidthCm       2.4
# PetalLengthCm      5.9
# PetalWidthCm       2.4
# Species            NaN
# dtype: object

# %%
print("\nStandard Deviation for each attribute:")
print(summary_stats.loc['std'])
# Out:
# Standard Deviation for each attribute:
# Id               43.445368
# SepalLengthCm     0.828066
# SepalWidthCm      0.433594
# PetalLengthCm      1.76442
# PetalWidthCm      0.763161
# Species                NaN
# Name: std, dtype: object

# %%
sns.pairplot(data, hue="Species")
plt.title("Pair Plot")
plt.show()

# %%
sns.scatterplot(x="SepalLengthCm", y= "PetalLengthCm", hue="Species", data=data)
plt.show()

# %%
data.hist(bins=20, figsize=(15, 10))
plt.show()

# %%
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Heatmap Correlation")
plt.show()
# Out:
# <ipython-input-60-c2c6ad780cda>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()
